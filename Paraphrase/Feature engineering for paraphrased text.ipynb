# %%
import pandas as pd
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# !pip install textstat
# !pip install py-readability-metrics
# !pip install readability-lxml
# Out:
# Requirement already satisfied: textstat in c:\users\asus\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: pyphen in c:\users\asus\anaconda3\lib\site-packages (from textstat) (0.14.0)
# Requirement already satisfied: py-readability-metrics in c:\users\asus\anaconda3\lib\site-packages (1.4.5)
# Requirement already satisfied: nltk in c:\users\asus\anaconda3\lib\site-packages (from py-readability-metrics) (3.7)
# Requirement already satisfied: tqdm in c:\users\asus\anaconda3\lib\site-packages (from nltk->py-readability-metrics) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\anaconda3\lib\site-packages (from nltk->py-readability-metrics) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\asus\anaconda3\lib\site-packages (from nltk->py-readability-metrics) (1.3.2)
# Requirement already satisfied: click in c:\users\asus\anaconda3\lib\site-packages (from nltk->py-readability-metrics) (8.0.4)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from click->nltk->py-readability-metrics) (0.4.6)
# Requirement already satisfied: readability-lxml in c:\users\asus\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: cssselect in c:\users\asus\anaconda3\lib\site-packages (from readability-lxml) (1.1.0)
# Requirement already satisfied: chardet in c:\users\asus\anaconda3\lib\site-packages (from readability-lxml) (4.0.0)
# Requirement already satisfied: lxml in c:\users\asus\anaconda3\lib\site-packages (from readability-lxml) (4.9.1)

# %%
paraphrased = pd.read_csv("Paraphrased.csv")
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased
# 0           1.0  The journey to understanding driverless cars b...
# 1           1.0  As a sixth-grade student, I believe that dispo...
# 2           1.0  Failure is a crucial aspect of achieving succe...
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...
# 4           1.0  I do not agree with the principal's decision t...
# ...         ...                                                ...
# 1995        1.0  I believe that driverless cars are a positive ...
# 1996        1.0  It is advisable to seek multiple opinions or a...
# 1997        1.0  While competition has its benefits in teaching...
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...
# 1999        1.0  Character traits are the distinct qualities th...
#
# [2000 rows x 4 columns]

# %%
ai_human = pd.read_csv("AI_Human.csv")

# %%
human = temp_df[temp_df['generated'] == 0].sample(1000)

# %%
human['paraphrased'] = human['text']
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased
# 253833  So y would be talking About now people should ...
# 86048   Since we had sent surveyors to Mars we have fo...
# 1306    Dear State Senator, I am here to inform you th...
# 282922  Dear Principal:\n\nI think that this situation...
# 247952  Hello, my name is Luke Merger, and I am in the...
# ...                                                   ...
# 131567  Dear State Senator,\n\nIt has come to my atten...
# 183160  Should teachers or students design summer proj...
# 122396  We should get rid of the electoral college bec...
# 145889  I think people should participate in the Seago...
# 240011  Dear principal,\n\nI believe all students shou...
#
# [1000 rows x 3 columns]

# %% [markdown]
# #### Length of text

# %%
paraphrased['length']=paraphrased['paraphrased'].apply(len)

# %%
human['length'] = human['paraphrased'].apply(len)

# %% [markdown]
# #### Polarity scores

# %%
text = paraphrased["paraphrased"]

polarity_scores = []
for i in range(len(text)):
    my_analyzer = analyzer.polarity_scores(text.iloc[i])
    polarity_scores.append(my_analyzer)
paraphrased['polarity_scores'] = polarity_scores
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased  length  \
# 0           1.0  The journey to understanding driverless cars b...    1534
# 1           1.0  As a sixth-grade student, I believe that dispo...    2260
# 2           1.0  Failure is a crucial aspect of achieving succe...     641
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...    2167
# 4           1.0  I do not agree with the principal's decision t...    2162
# ...         ...                                                ...     ...
# 1995        1.0  I believe that driverless cars are a positive ...    1185
# 1996        1.0  It is advisable to seek multiple opinions or a...     826
# 1997        1.0  While competition has its benefits in teaching...     865
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...    1869
# 1999        1.0  Character traits are the distinct qualities th...    1461
#
#                                         polarity_scores
# 0     {'neg': 0.052, 'neu': 0.739, 'pos': 0.209, 'co...
# 1     {'neg': 0.145, 'neu': 0.761, 'pos': 0.094, 'co...
# 2     {'neg': 0.153, 'neu': 0.572, 'pos': 0.275, 'co...
# 3     {'neg': 0.03, 'neu': 0.807, 'pos': 0.163, 'com...
# 4     {'neg': 0.06, 'neu': 0.759, 'pos': 0.181, 'com...
# ...                                                 ...
# 1995  {'neg': 0.036, 'neu': 0.77, 'pos': 0.194, 'com...
# 1996  {'neg': 0.1, 'neu': 0.752, 'pos': 0.148, 'comp...
# 1997  {'neg': 0.061, 'neu': 0.775, 'pos': 0.164, 'co...
# 1998  {'neg': 0.04, 'neu': 0.783, 'pos': 0.176, 'com...
# 1999  {'neg': 0.046, 'neu': 0.804, 'pos': 0.15, 'com...
#
# [2000 rows x 6 columns]

# %%
text_human = human['paraphrased']
polarity_scores = []

for i in range(len(text_human)):
    my_analyzer = analyzer.polarity_scores(text_human.iloc[i])
    polarity_scores.append(my_analyzer)
human['polarity_scores'] = polarity_scores
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased  length  \
# 253833  So y would be talking About now people should ...    3267
# 86048   Since we had sent surveyors to Mars we have fo...    2261
# 1306    Dear State Senator, I am here to inform you th...    3348
# 282922  Dear Principal:\n\nI think that this situation...     880
# 247952  Hello, my name is Luke Merger, and I am in the...    2395
# ...                                                   ...     ...
# 131567  Dear State Senator,\n\nIt has come to my atten...    2767
# 183160  Should teachers or students design summer proj...    2870
# 122396  We should get rid of the electoral college bec...    4392
# 145889  I think people should participate in the Seago...    1657
# 240011  Dear principal,\n\nI believe all students shou...    1799
#
#                                           polarity_scores
# 253833  {'neg': 0.062, 'neu': 0.745, 'pos': 0.193, 'co...
# 86048   {'neg': 0.036, 'neu': 0.86, 'pos': 0.103, 'com...
# 1306    {'neg': 0.07, 'neu': 0.778, 'pos': 0.152, 'com...
# 282922  {'neg': 0.027, 'neu': 0.891, 'pos': 0.082, 'co...
# 247952  {'neg': 0.042, 'neu': 0.814, 'pos': 0.145, 'co...
# ...                                                   ...
# 131567  {'neg': 0.04, 'neu': 0.81, 'pos': 0.15, 'compo...
# 183160  {'neg': 0.061, 'neu': 0.765, 'pos': 0.174, 'co...
# 122396  {'neg': 0.09, 'neu': 0.786, 'pos': 0.124, 'com...
# 145889  {'neg': 0.012, 'neu': 0.798, 'pos': 0.19, 'com...
# 240011  {'neg': 0.09, 'neu': 0.733, 'pos': 0.178, 'com...
#
# [1000 rows x 5 columns]

# %%
def unpack_dictionary(paraphrased):
    return pd.Series(paraphrased['polarity_scores'])

new_columns = paraphrased.apply(unpack_dictionary, axis=1)
paraphrased = pd.concat([paraphrased, new_columns], axis=1)
paraphrased.drop(['polarity_scores'], axis=1, inplace=True)
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased  length  \
# 0           1.0  The journey to understanding driverless cars b...    1534
# 1           1.0  As a sixth-grade student, I believe that dispo...    2260
# 2           1.0  Failure is a crucial aspect of achieving succe...     641
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...    2167
# 4           1.0  I do not agree with the principal's decision t...    2162
# ...         ...                                                ...     ...
# 1995        1.0  I believe that driverless cars are a positive ...    1185
# 1996        1.0  It is advisable to seek multiple opinions or a...     826
# 1997        1.0  While competition has its benefits in teaching...     865
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...    1869
# 1999        1.0  Character traits are the distinct qualities th...    1461
#
#         neg    neu    pos  compound
# 0     0.052  0.739  0.209    0.9869
# 1     0.145  0.761  0.094   -0.9638
# 2     0.153  0.572  0.275    0.9495
# 3     0.030  0.807  0.163    0.9943
# 4     0.060  0.759  0.181    0.9873
# ...     ...    ...    ...       ...
# 1995  0.036  0.770  0.194    0.9798
# 1996  0.100  0.752  0.148    0.7541
# 1997  0.061  0.775  0.164    0.9149
# 1998  0.040  0.783  0.176    0.9806
# 1999  0.046  0.804  0.150    0.9637
#
# [2000 rows x 9 columns]

# %%
new_columns = human.apply(unpack_dictionary, axis=1)
human = pd.concat([human, new_columns], axis=1)
human.drop(['polarity_scores'], axis=1, inplace=True)
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
# ...                                                   ...     ...    ...
# 131567  Dear State Senator,\n\nIt has come to my atten...    2767  0.040
# 183160  Should teachers or students design summer proj...    2870  0.061
# 122396  We should get rid of the electoral college bec...    4392  0.090
# 145889  I think people should participate in the Seago...    1657  0.012
# 240011  Dear principal,\n\nI believe all students shou...    1799  0.090
#
#           neu    pos  compound
# 253833  0.745  0.193    0.9988
# 86048   0.860  0.103    0.9823
# 1306    0.778  0.152    0.9947
# 282922  0.891  0.082    0.6808
# 247952  0.814  0.145    0.9936
# ...       ...    ...       ...
# 131567  0.810  0.150    0.9962
# 183160  0.765  0.174    0.9971
# 122396  0.786  0.124    0.9826
# 145889  0.798  0.190    0.9963
# 240011  0.733  0.178    0.9768
#
# [1000 rows x 8 columns]

# %% [markdown]
# #### subjectivity scores

# %%
subjectivity_scores = []
for i in range(len(text)):
    sub_score = TextBlob(text.iloc[i]).subjectivity
    subjectivity_scores.append(sub_score)
paraphrased['subjectivity_score'] = subjectivity_scores
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased  length  \
# 0           1.0  The journey to understanding driverless cars b...    1534
# 1           1.0  As a sixth-grade student, I believe that dispo...    2260
# 2           1.0  Failure is a crucial aspect of achieving succe...     641
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...    2167
# 4           1.0  I do not agree with the principal's decision t...    2162
# ...         ...                                                ...     ...
# 1995        1.0  I believe that driverless cars are a positive ...    1185
# 1996        1.0  It is advisable to seek multiple opinions or a...     826
# 1997        1.0  While competition has its benefits in teaching...     865
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...    1869
# 1999        1.0  Character traits are the distinct qualities th...    1461
#
#         neg    neu    pos  compound  subjectivity_score
# 0     0.052  0.739  0.209    0.9869            0.448016
# 1     0.145  0.761  0.094   -0.9638            0.445370
# 2     0.153  0.572  0.275    0.9495            0.505303
# 3     0.030  0.807  0.163    0.9943            0.508333
# 4     0.060  0.759  0.181    0.9873            0.503571
# ...     ...    ...    ...       ...                 ...
# 1995  0.036  0.770  0.194    0.9798            0.527214
# 1996  0.100  0.752  0.148    0.7541            0.554342
# 1997  0.061  0.775  0.164    0.9149            0.492308
# 1998  0.040  0.783  0.176    0.9806            0.516912
# 1999  0.046  0.804  0.150    0.9637            0.388714
#
# [2000 rows x 10 columns]

# %%
subjectivity_scores = []
for i in range(len(text_human)):
    sub_score = TextBlob(text_human.iloc[i]).subjectivity
    subjectivity_scores.append(sub_score)
human['subjectivity_score'] = subjectivity_scores
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
# ...                                                   ...     ...    ...
# 131567  Dear State Senator,\n\nIt has come to my atten...    2767  0.040
# 183160  Should teachers or students design summer proj...    2870  0.061
# 122396  We should get rid of the electoral college bec...    4392  0.090
# 145889  I think people should participate in the Seago...    1657  0.012
# 240011  Dear principal,\n\nI believe all students shou...    1799  0.090
#
#           neu    pos  compound  subjectivity_score
# 253833  0.745  0.193    0.9988            0.508549
# 86048   0.860  0.103    0.9823            0.532793
# 1306    0.778  0.152    0.9947            0.602583
# 282922  0.891  0.082    0.6808            0.333333
# 247952  0.814  0.145    0.9936            0.407160
# ...       ...    ...       ...                 ...
# 131567  0.810  0.150    0.9962            0.601775
# 183160  0.765  0.174    0.9971            0.504802
# 122396  0.786  0.124    0.9826            0.584332
# 145889  0.798  0.190    0.9963            0.404202
# 240011  0.733  0.178    0.9768            0.537984
#
# [1000 rows x 9 columns]

# %% [markdown]
# #### Reading ease / kincaid grade

# %%
import textstat

def calculate_flesch_reading_ease(text):
    return textstat.flesch_reading_ease(text)

# Apply the function to the 'text' column
human['flesch_reading_ease_score'] = human['paraphrased'].apply(calculate_flesch_reading_ease)

def calculate_flesch_kincaid(text):
#     return Readability(text).flesch_kincaid()
    return textstat.flesch_kincaid_grade(text)

human['flesch_kincaid_grade'] = human['paraphrased'].apply(calculate_flesch_kincaid)
human.head()
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
#
#         flesch_kincaid_grade
# 253833                   9.9
# 86048                    7.3
# 1306                     9.1
# 282922                   8.1
# 247952                   5.1

# %%
import textstat

def calculate_flesch_reading_ease(text):
    return textstat.flesch_reading_ease(text)

# Apply the function to the 'text' column
paraphrased['flesch_reading_ease_score'] = paraphrased['paraphrased'].apply(calculate_flesch_reading_ease)

def calculate_flesch_kincaid(text):
#     return Readability(text).flesch_kincaid()
    return textstat.flesch_kincaid_grade(text)

paraphrased['flesch_kincaid_grade'] = paraphrased['paraphrased'].apply(calculate_flesch_kincaid)
paraphrased.head()
# Out:
#    Unnamed: 0                                               text  generated  \
# 0       79241  \n\nStarting our journey towards understanding...        1.0
# 1      386827  As a student PN grade 6, I believe that single...        1.0
# 2       84966  Failure plays a crucial role in the pursuit of...        1.0
# 3       43982  Introduction:\n\nAs a scientist at NASA, I hav...        1.0
# 4       97180  I disagree Pith the principal's decision that ...        1.0
#
#                                          paraphrased  length    neg    neu  \
# 0  The journey to understanding driverless cars b...    1534  0.052  0.739
# 1  As a sixth-grade student, I believe that dispo...    2260  0.145  0.761
# 2  Failure is a crucial aspect of achieving succe...     641  0.153  0.572
# 3  Introduction:\n\nAs a scientist at NASA, I hav...    2167  0.030  0.807
# 4  I do not agree with the principal's decision t...    2162  0.060  0.759
#
#      pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 0  0.209    0.9869            0.448016                      14.49
# 1  0.094   -0.9638            0.445370                      44.54
# 2  0.275    0.9495            0.505303                      49.96
# 3  0.163    0.9943            0.508333                      50.26
# 4  0.181    0.9873            0.503571                      17.23
#
#    flesch_kincaid_grade
# 0                  16.9
# 1                  11.6
# 2                  11.6
# 3                  11.4
# 4                  15.8

# %% [markdown]
# #### Perplexity

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

# %%
# Load pre-trained GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Load pre-trained GPT-2 language model
model = GPT2LMHeadModel.from_pretrained("gpt2")


def calculate_perplexity(text):
    # Tokenizes the input text, but some are too long, thus truncation is activated
    input_ids = tokenizer.encode(text, return_tensors="pt", truncation = True)

    # Forward pass through the language model
    with torch.no_grad():
        outputs = model(input_ids=input_ids, labels=input_ids)
    
    # Compute perplexity from the loss
    loss = outputs.loss
    perplexity = torch.exp(loss)
    
    return perplexity.item()

paraphrased['Perplexity Score'] = paraphrased['paraphrased'].apply(calculate_perplexity) 
paraphrased.head()
# Out:
#    Unnamed: 0                                               text  generated  \
# 0       79241  \n\nStarting our journey towards understanding...        1.0
# 1      386827  As a student PN grade 6, I believe that single...        1.0
# 2       84966  Failure plays a crucial role in the pursuit of...        1.0
# 3       43982  Introduction:\n\nAs a scientist at NASA, I hav...        1.0
# 4       97180  I disagree Pith the principal's decision that ...        1.0
#
#                                          paraphrased  length    neg    neu  \
# 0  The journey to understanding driverless cars b...    1534  0.052  0.739
# 1  As a sixth-grade student, I believe that dispo...    2260  0.145  0.761
# 2  Failure is a crucial aspect of achieving succe...     641  0.153  0.572
# 3  Introduction:\n\nAs a scientist at NASA, I hav...    2167  0.030  0.807
# 4  I do not agree with the principal's decision t...    2162  0.060  0.759
#
#      pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 0  0.209    0.9869            0.448016                      14.49
# 1  0.094   -0.9638            0.445370                      44.54
# 2  0.275    0.9495            0.505303                      49.96
# 3  0.163    0.9943            0.508333                      50.26
# 4  0.181    0.9873            0.503571                      17.23
#
#    flesch_kincaid_grade  Perplexity Score
# 0                  16.9         14.795133
# 1                  11.6         10.150987
# 2                  11.6         12.728074
# 3                  11.4         10.289102
# 4                  15.8         11.612104

# %%
# Load pre-trained GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Load pre-trained GPT-2 language model
model = GPT2LMHeadModel.from_pretrained("gpt2")


def calculate_perplexity(text):
    # Tokenizes the input text, but some are too long, thus truncation is activated
    input_ids = tokenizer.encode(text, return_tensors="pt", truncation = True)

    # Forward pass through the language model
    with torch.no_grad():
        outputs = model(input_ids=input_ids, labels=input_ids)
    
    # Compute perplexity from the loss
    loss = outputs.loss
    perplexity = torch.exp(loss)
    
    return perplexity.item()

human['Perplexity Score'] = human['paraphrased'].apply(calculate_perplexity) 
human.head()
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
#
#         flesch_kincaid_grade  Perplexity Score
# 253833                   9.9         88.486298
# 86048                    7.3         23.002769
# 1306                     9.1         27.911303
# 282922                   8.1         29.663225
# 247952                   5.1         17.708487

# %% [markdown]
# #### Discourse markers

# %%
dcl_list = ['and','or','also','much', 'then','again', 'too', 'increasingly', 'similarly', 'further', 'namely', 'thus', 'indeed',
 'e.g.', 'specifically', 'i.e.', 'especially', 'usually', 'certainly', 'generally', 'extremely', 'mostly', 'actually', 'basically',
 'surely', 'inevitably', 'clearly', 'approximately', 'resembling', 'exactly', 'unlike', 'because', 'therefore', 'if', 'somehow',
 'hence', 'consequently', 'thereby', 'otherwise', 'since', 'however', 'while', 'althoughthough', 'instead', 'yet', 'worse',
 'except', 'whereas', 'albeit', 'admittedly', 'sometimes', 'until', 'eventually', 'constantly', 'meanwhile', 'beforehand',
 'meantime', 'overall', 'finally', 'firstly', 'secondly', 'lastly', 'conclude', 'summarize', 'altogether', 'briefly']

dcl_count_list = []
paraphrased['split_text'] = paraphrased['paraphrased'].str.split(' ')

# Iterate through each word in the DataFrame
for text_list in paraphrased['split_text']:
    dcl_count = 0
    # Check if the word is in the word list
    for word in text_list:
        if word in dcl_list:
        # Increment counter if the word is found
            dcl_count += 1
    dcl_count_list.append(dcl_count)
    
paraphrased['no_discourse_markers'] = dcl_count_list
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased  length  \
# 0           1.0  The journey to understanding driverless cars b...    1534
# 1           1.0  As a sixth-grade student, I believe that dispo...    2260
# 2           1.0  Failure is a crucial aspect of achieving succe...     641
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...    2167
# 4           1.0  I do not agree with the principal's decision t...    2162
# ...         ...                                                ...     ...
# 1995        1.0  I believe that driverless cars are a positive ...    1185
# 1996        1.0  It is advisable to seek multiple opinions or a...     826
# 1997        1.0  While competition has its benefits in teaching...     865
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...    1869
# 1999        1.0  Character traits are the distinct qualities th...    1461
#
#         neg    neu    pos  compound  subjectivity_score  \
# 0     0.052  0.739  0.209    0.9869            0.448016
# 1     0.145  0.761  0.094   -0.9638            0.445370
# 2     0.153  0.572  0.275    0.9495            0.505303
# 3     0.030  0.807  0.163    0.9943            0.508333
# 4     0.060  0.759  0.181    0.9873            0.503571
# ...     ...    ...    ...       ...                 ...
# 1995  0.036  0.770  0.194    0.9798            0.527214
# 1996  0.100  0.752  0.148    0.7541            0.554342
# 1997  0.061  0.775  0.164    0.9149            0.492308
# 1998  0.040  0.783  0.176    0.9806            0.516912
# 1999  0.046  0.804  0.150    0.9637            0.388714
#
#       flesch_reading_ease_score  flesch_kincaid_grade  Perplexity Score  \
# 0                         14.49                  16.9         14.795133
# 1                         44.54                  11.6         10.150987
# 2                         49.96                  11.6         12.728074
# 3                         50.26                  11.4         10.289102
# 4                         17.23                  15.8         11.612104
# ...                         ...                   ...               ...
# 1995                      28.64                  13.5         10.796640
# 1996                      26.10                  14.5         28.091429
# 1997                      28.37                  15.7         21.220530
# 1998                      21.43                  16.3         13.270144
# 1999                      26.91                  14.2         14.853067
#
#                                              split_text  no_discourse_markers
# 0     [The, journey, to, understanding, driverless, ...                    18
# 1     [As, a, sixth-grade, student,, I, believe, tha...                    22
# 2     [Failure, is, a, crucial, aspect, of, achievin...                     5
# 3     [Introduction:\n\nAs, a, scientist, at, NASA,,...                     7
# 4     [I, do, not, agree, with, the, principal's, de...                    18
# ...                                                 ...                   ...
# 1995  [I, believe, that, driverless, cars, are, a, p...                     7
# 1996  [It, is, advisable, to, seek, multiple, opinio...                     9
# 1997  [While, competition, has, its, benefits, in, t...                     8
# 1998  [Title:, The, Impact, of, Autonomous, Vehicles...                    13
# 1999  [Character, traits, are, the, distinct, qualit...                    17
#
# [2000 rows x 15 columns]

# %%
dcl_list = ['and','or','also','much', 'then','again', 'too', 'increasingly', 'similarly', 'further', 'namely', 'thus', 'indeed',
 'e.g.', 'specifically', 'i.e.', 'especially', 'usually', 'certainly', 'generally', 'extremely', 'mostly', 'actually', 'basically',
 'surely', 'inevitably', 'clearly', 'approximately', 'resembling', 'exactly', 'unlike', 'because', 'therefore', 'if', 'somehow',
 'hence', 'consequently', 'thereby', 'otherwise', 'since', 'however', 'while', 'althoughthough', 'instead', 'yet', 'worse',
 'except', 'whereas', 'albeit', 'admittedly', 'sometimes', 'until', 'eventually', 'constantly', 'meanwhile', 'beforehand',
 'meantime', 'overall', 'finally', 'firstly', 'secondly', 'lastly', 'conclude', 'summarize', 'altogether', 'briefly']

dcl_count_list = []
human['split_text'] = human['paraphrased'].str.split(' ')

# Iterate through each word in the DataFrame
for text_list in human['split_text']:
    dcl_count = 0
    # Check if the word is in the word list
    for word in text_list:
        if word in dcl_list:
        # Increment counter if the word is found
            dcl_count += 1
    dcl_count_list.append(dcl_count)
    
human['no_discourse_markers'] = dcl_count_list
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
# ...                                                   ...     ...    ...
# 131567  Dear State Senator,\n\nIt has come to my atten...    2767  0.040
# 183160  Should teachers or students design summer proj...    2870  0.061
# 122396  We should get rid of the electoral college bec...    4392  0.090
# 145889  I think people should participate in the Seago...    1657  0.012
# 240011  Dear principal,\n\nI believe all students shou...    1799  0.090
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
# ...       ...    ...       ...                 ...                        ...
# 131567  0.810  0.150    0.9962            0.601775                      71.95
# 183160  0.765  0.174    0.9971            0.504802                      67.99
# 122396  0.786  0.124    0.9826            0.584332                      61.97
# 145889  0.798  0.190    0.9963            0.404202                      77.16
# 240011  0.733  0.178    0.9768            0.537984                      83.05
#
#         flesch_kincaid_grade  Perplexity Score  \
# 253833                   9.9         88.486298
# 86048                    7.3         23.002769
# 1306                     9.1         27.911303
# 282922                   8.1         29.663225
# 247952                   5.1         17.708487
# ...                      ...               ...
# 131567                   7.2         20.290138
# 183160                   8.8         17.920427
# 122396                   9.0         22.413544
# 145889                   7.3         38.715046
# 240011                   5.1         17.740433
#
#                                                split_text  \
# 253833  [So, y, would, be, talking, About, now, people...
# 86048   [Since, we, had, sent, surveyors, to, Mars, we...
# 1306    [Dear, State, Senator,, I, am, here, to, infor...
# 282922  [Dear, Principal:\n\nI, think, that, this, sit...
# 247952  [Hello,, my, name, is, Luke, Merger,, and, I, ...
# ...                                                   ...
# 131567  [Dear, State, Senator,\n\nIt, has, come, to, m...
# 183160  [Should, teachers, or, students, design, summe...
# 122396  [We, should, get, rid, of, the, electoral, col...
# 145889  [I, think, people, should, participate, in, th...
# 240011  [Dear, principal,\n\nI, believe, all, students...
#
#         no_discourse_markers
# 253833                    28
# 86048                     26
# 1306                      24
# 282922                    10
# 247952                    19
# ...                      ...
# 131567                    26
# 183160                    23
# 122396                    30
# 145889                    21
# 240011                    24
#
# [1000 rows x 14 columns]

# %% [markdown]
# #### Pronouns

# %%
pronouns_list = ['i','you','he','him','her','she','they','them','it','we','me','us']

pronouns_count_list = []
paraphrased['split_text'] = paraphrased['paraphrased'].str.split(' ')

# Iterate through each word in the DataFrame
for text_list in paraphrased['split_text']:
    pronouns_count = 0
    # Check if the word is in the word list
    for word in text_list:
        if word in pronouns_list:
        # Increment counter if the word is found
            pronouns_count += 1
    pronouns_count_list.append(pronouns_count)
    
# Display the count
paraphrased['no_pronouns'] = pronouns_count_list
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased  length  \
# 0           1.0  The journey to understanding driverless cars b...    1534
# 1           1.0  As a sixth-grade student, I believe that dispo...    2260
# 2           1.0  Failure is a crucial aspect of achieving succe...     641
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...    2167
# 4           1.0  I do not agree with the principal's decision t...    2162
# ...         ...                                                ...     ...
# 1995        1.0  I believe that driverless cars are a positive ...    1185
# 1996        1.0  It is advisable to seek multiple opinions or a...     826
# 1997        1.0  While competition has its benefits in teaching...     865
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...    1869
# 1999        1.0  Character traits are the distinct qualities th...    1461
#
#         neg    neu    pos  compound  subjectivity_score  \
# 0     0.052  0.739  0.209    0.9869            0.448016
# 1     0.145  0.761  0.094   -0.9638            0.445370
# 2     0.153  0.572  0.275    0.9495            0.505303
# 3     0.030  0.807  0.163    0.9943            0.508333
# 4     0.060  0.759  0.181    0.9873            0.503571
# ...     ...    ...    ...       ...                 ...
# 1995  0.036  0.770  0.194    0.9798            0.527214
# 1996  0.100  0.752  0.148    0.7541            0.554342
# 1997  0.061  0.775  0.164    0.9149            0.492308
# 1998  0.040  0.783  0.176    0.9806            0.516912
# 1999  0.046  0.804  0.150    0.9637            0.388714
#
#       flesch_reading_ease_score  flesch_kincaid_grade  Perplexity Score  \
# 0                         14.49                  16.9         14.795133
# 1                         44.54                  11.6         10.150987
# 2                         49.96                  11.6         12.728074
# 3                         50.26                  11.4         10.289102
# 4                         17.23                  15.8         11.612104
# ...                         ...                   ...               ...
# 1995                      28.64                  13.5         10.796640
# 1996                      26.10                  14.5         28.091429
# 1997                      28.37                  15.7         21.220530
# 1998                      21.43                  16.3         13.270144
# 1999                      26.91                  14.2         14.853067
#
#                                              split_text  no_discourse_markers  \
# 0     [The, journey, to, understanding, driverless, ...                    18
# 1     [As, a, sixth-grade, student,, I, believe, tha...                    22
# 2     [Failure, is, a, crucial, aspect, of, achievin...                     5
# 3     [Introduction:\n\nAs, a, scientist, at, NASA,,...                     7
# 4     [I, do, not, agree, with, the, principal's, de...                    18
# ...                                                 ...                   ...
# 1995  [I, believe, that, driverless, cars, are, a, p...                     7
# 1996  [It, is, advisable, to, seek, multiple, opinio...                     9
# 1997  [While, competition, has, its, benefits, in, t...                     8
# 1998  [Title:, The, Impact, of, Autonomous, Vehicles...                    13
# 1999  [Character, traits, are, the, distinct, qualit...                    17
#
#       no_pronouns
# 0               0
# 1               6
# 2               8
# 3               7
# 4               3
# ...           ...
# 1995            2
# 1996            0
# 1997            1
# 1998            2
# 1999            1
#
# [2000 rows x 16 columns]

# %%
pronouns_list = ['i','you','he','him','her','she','they','them','it','we','me','us']

pronouns_count_list = []
human['split_text'] = human['paraphrased'].str.split(' ')

# Iterate through each word in the DataFrame
for text_list in human['paraphrased']:
    pronouns_count = 0
    # Check if the word is in the word list
    for word in text_list:
        if word in pronouns_list:
        # Increment counter if the word is found
            pronouns_count += 1
    pronouns_count_list.append(pronouns_count)
    
# Display the count
human['no_pronouns'] = pronouns_count_list
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
# ...                                                   ...     ...    ...
# 131567  Dear State Senator,\n\nIt has come to my atten...    2767  0.040
# 183160  Should teachers or students design summer proj...    2870  0.061
# 122396  We should get rid of the electoral college bec...    4392  0.090
# 145889  I think people should participate in the Seago...    1657  0.012
# 240011  Dear principal,\n\nI believe all students shou...    1799  0.090
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
# ...       ...    ...       ...                 ...                        ...
# 131567  0.810  0.150    0.9962            0.601775                      71.95
# 183160  0.765  0.174    0.9971            0.504802                      67.99
# 122396  0.786  0.124    0.9826            0.584332                      61.97
# 145889  0.798  0.190    0.9963            0.404202                      77.16
# 240011  0.733  0.178    0.9768            0.537984                      83.05
#
#         flesch_kincaid_grade  Perplexity Score  \
# 253833                   9.9         88.486298
# 86048                    7.3         23.002769
# 1306                     9.1         27.911303
# 282922                   8.1         29.663225
# 247952                   5.1         17.708487
# ...                      ...               ...
# 131567                   7.2         20.290138
# 183160                   8.8         17.920427
# 122396                   9.0         22.413544
# 145889                   7.3         38.715046
# 240011                   5.1         17.740433
#
#                                                split_text  \
# 253833  [So, y, would, be, talking, About, now, people...
# 86048   [Since, we, had, sent, surveyors, to, Mars, we...
# 1306    [Dear, State, Senator,, I, am, here, to, infor...
# 282922  [Dear, Principal:\n\nI, think, that, this, sit...
# 247952  [Hello,, my, name, is, Luke, Merger,, and, I, ...
# ...                                                   ...
# 131567  [Dear, State, Senator,\n\nIt, has, come, to, m...
# 183160  [Should, teachers, or, students, design, summe...
# 122396  [We, should, get, rid, of, the, electoral, col...
# 145889  [I, think, people, should, participate, in, th...
# 240011  [Dear, principal,\n\nI, believe, all, students...
#
#         no_discourse_markers  no_pronouns
# 253833                    28          151
# 86048                     26          127
# 1306                      24          171
# 282922                    10           42
# 247952                    19           95
# ...                      ...          ...
# 131567                    26          118
# 183160                    23          120
# 122396                    30          208
# 145889                    21           68
# 240011                    24           81
#
# [1000 rows x 15 columns]

# %% [markdown]
# #### mean words per sentence

# %%
paraphrased['mean_words_per_sentence'] = paraphrased['paraphrased'].str.split(' ').str.len()/paraphrased['paraphrased'].str.split('.').str.len()
paraphrased
# Out:
#       Unnamed: 0                                               text  \
# 0          79241  \n\nStarting our journey towards understanding...
# 1         386827  As a student PN grade 6, I believe that single...
# 2          84966  Failure plays a crucial role in the pursuit of...
# 3          43982  Introduction:\n\nAs a scientist at NASA, I hav...
# 4          97180  I disagree Pith the principal's decision that ...
# ...          ...                                                ...
# 1995      468700  I think driverless cars is a good idea. They w...
# 1996      234643  Seeking multiple opinions when making an impor...
# 1997       20920  There is no denying that competition has it's ...
# 1998       33604  Title: The Revolution of Driverless Cars: A Ga...
# 1999      226201  Character traits are the unique qualities that...
#
#       generated                                        paraphrased  length  \
# 0           1.0  The journey to understanding driverless cars b...    1534
# 1           1.0  As a sixth-grade student, I believe that dispo...    2260
# 2           1.0  Failure is a crucial aspect of achieving succe...     641
# 3           1.0  Introduction:\n\nAs a scientist at NASA, I hav...    2167
# 4           1.0  I do not agree with the principal's decision t...    2162
# ...         ...                                                ...     ...
# 1995        1.0  I believe that driverless cars are a positive ...    1185
# 1996        1.0  It is advisable to seek multiple opinions or a...     826
# 1997        1.0  While competition has its benefits in teaching...     865
# 1998        1.0  Title: The Impact of Autonomous Vehicles on Ro...    1869
# 1999        1.0  Character traits are the distinct qualities th...    1461
#
#         neg    neu    pos  compound  subjectivity_score  \
# 0     0.052  0.739  0.209    0.9869            0.448016
# 1     0.145  0.761  0.094   -0.9638            0.445370
# 2     0.153  0.572  0.275    0.9495            0.505303
# 3     0.030  0.807  0.163    0.9943            0.508333
# 4     0.060  0.759  0.181    0.9873            0.503571
# ...     ...    ...    ...       ...                 ...
# 1995  0.036  0.770  0.194    0.9798            0.527214
# 1996  0.100  0.752  0.148    0.7541            0.554342
# 1997  0.061  0.775  0.164    0.9149            0.492308
# 1998  0.040  0.783  0.176    0.9806            0.516912
# 1999  0.046  0.804  0.150    0.9637            0.388714
#
#       flesch_reading_ease_score  flesch_kincaid_grade  Perplexity Score  \
# 0                         14.49                  16.9         14.795133
# 1                         44.54                  11.6         10.150987
# 2                         49.96                  11.6         12.728074
# 3                         50.26                  11.4         10.289102
# 4                         17.23                  15.8         11.612104
# ...                         ...                   ...               ...
# 1995                      28.64                  13.5         10.796640
# 1996                      26.10                  14.5         28.091429
# 1997                      28.37                  15.7         21.220530
# 1998                      21.43                  16.3         13.270144
# 1999                      26.91                  14.2         14.853067
#
#                                              split_text  no_discourse_markers  \
# 0     [The, journey, to, understanding, driverless, ...                    18
# 1     [As, a, sixth-grade, student,, I, believe, tha...                    22
# 2     [Failure, is, a, crucial, aspect, of, achievin...                     5
# 3     [Introduction:\n\nAs, a, scientist, at, NASA,,...                     7
# 4     [I, do, not, agree, with, the, principal's, de...                    18
# ...                                                 ...                   ...
# 1995  [I, believe, that, driverless, cars, are, a, p...                     7
# 1996  [It, is, advisable, to, seek, multiple, opinio...                     9
# 1997  [While, competition, has, its, benefits, in, t...                     8
# 1998  [Title:, The, Impact, of, Autonomous, Vehicles...                    13
# 1999  [Character, traits, are, the, distinct, qualit...                    17
#
#       no_pronouns  mean_words_per_sentence
# 0               0                20.300000
# 1               6                17.050000
# 2               8                17.666667
# 3               7                19.277778
# 4               3                18.562500
# ...           ...                      ...
# 1995            2                15.363636
# 1996            0                16.857143
# 1997            1                21.500000
# 1998            2                16.125000
# 1999            1                17.083333
#
# [2000 rows x 17 columns]

# %%
human['mean_words_per_sentence'] = human['paraphrased'].str.split(' ').str.len()/human['paraphrased'].str.split('.').str.len()
human
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
# ...                                                   ...        ...
# 131567  Dear State Senator,\n\nIt has come to my atten...        0.0
# 183160  Should teachers or students design summer proj...        0.0
# 122396  We should get rid of the electoral college bec...        0.0
# 145889  I think people should participate in the Seago...        0.0
# 240011  Dear principal,\n\nI believe all students shou...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
# ...                                                   ...     ...    ...
# 131567  Dear State Senator,\n\nIt has come to my atten...    2767  0.040
# 183160  Should teachers or students design summer proj...    2870  0.061
# 122396  We should get rid of the electoral college bec...    4392  0.090
# 145889  I think people should participate in the Seago...    1657  0.012
# 240011  Dear principal,\n\nI believe all students shou...    1799  0.090
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
# ...       ...    ...       ...                 ...                        ...
# 131567  0.810  0.150    0.9962            0.601775                      71.95
# 183160  0.765  0.174    0.9971            0.504802                      67.99
# 122396  0.786  0.124    0.9826            0.584332                      61.97
# 145889  0.798  0.190    0.9963            0.404202                      77.16
# 240011  0.733  0.178    0.9768            0.537984                      83.05
#
#         flesch_kincaid_grade  Perplexity Score  \
# 253833                   9.9         88.486298
# 86048                    7.3         23.002769
# 1306                     9.1         27.911303
# 282922                   8.1         29.663225
# 247952                   5.1         17.708487
# ...                      ...               ...
# 131567                   7.2         20.290138
# 183160                   8.8         17.920427
# 122396                   9.0         22.413544
# 145889                   7.3         38.715046
# 240011                   5.1         17.740433
#
#                                                split_text  \
# 253833  [So, y, would, be, talking, About, now, people...
# 86048   [Since, we, had, sent, surveyors, to, Mars, we...
# 1306    [Dear, State, Senator,, I, am, here, to, infor...
# 282922  [Dear, Principal:\n\nI, think, that, this, sit...
# 247952  [Hello,, my, name, is, Luke, Merger,, and, I, ...
# ...                                                   ...
# 131567  [Dear, State, Senator,\n\nIt, has, come, to, m...
# 183160  [Should, teachers, or, students, design, summe...
# 122396  [We, should, get, rid, of, the, electoral, col...
# 145889  [I, think, people, should, participate, in, th...
# 240011  [Dear, principal,\n\nI, believe, all, students...
#
#         no_discourse_markers  no_pronouns  mean_words_per_sentence
# 253833                    28          151                24.680000
# 86048                     26          127                18.260870
# 1306                      24          171                22.296296
# 282922                    10           42                21.125000
# 247952                    19           95                13.117647
# ...                      ...          ...                      ...
# 131567                    26          118                10.659574
# 183160                    23          120                20.000000
# 122396                    30          208                15.851064
# 145889                    21           68                18.000000
# 240011                    24           81                12.923077
#
# [1000 rows x 16 columns]

# %% [markdown]
# #### Number of grammatical errors

# %%
import re

# Define regular expressions for common grammatical errors
error_patterns = [
    (r'\b\w+(?:\'[st])\b', "Use 's or 'd instead of '"),
    (r'\bis\s+(?:\w+ing\b|\w+\s)', "Use the correct form of the verb after 'is'"),
    (r'\b(?:\w+ed|\w+en)\s+\w+', "Check for correct verb forms (past participles)"),
    (r'\b(?:a|an)\s+[aeiou]', "Use 'a' or 'an' correctly before a word"),
    (r'\b(?:too|to|two)\b', "Use the correct form of 'to'"),
    (r'\b(?:their|there|they\'re)\b', "Use the correct form of 'their', 'there', or 'they're'"),
    (r'\b(?:your|you\'re)\b', "Use the correct form of 'your' or 'you're'"),
    (r'\b(?:its|it\'s)\b', "Use the correct form of 'its' or 'it's'")
]

# Function to detect grammatical errors using regular expressions
def detect_grammatical_errors(text):
    errors = []
    for pattern, description in error_patterns:
        matches = re.findall(pattern, text)
        if matches:
            errors.extend([(match, description) for match in matches])
    return len(errors)

# Apply function to DataFrame
paraphrased['grammatical_errors'] = paraphrased['paraphrased'].apply(detect_grammatical_errors)
paraphrased.head()
# Out:
#    Unnamed: 0                                               text  generated  \
# 0       79241  \n\nStarting our journey towards understanding...        1.0
# 1      386827  As a student PN grade 6, I believe that single...        1.0
# 2       84966  Failure plays a crucial role in the pursuit of...        1.0
# 3       43982  Introduction:\n\nAs a scientist at NASA, I hav...        1.0
# 4       97180  I disagree Pith the principal's decision that ...        1.0
#
#                                          paraphrased  length    neg    neu  \
# 0  The journey to understanding driverless cars b...    1534  0.052  0.739
# 1  As a sixth-grade student, I believe that dispo...    2260  0.145  0.761
# 2  Failure is a crucial aspect of achieving succe...     641  0.153  0.572
# 3  Introduction:\n\nAs a scientist at NASA, I hav...    2167  0.030  0.807
# 4  I do not agree with the principal's decision t...    2162  0.060  0.759
#
#      pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 0  0.209    0.9869            0.448016                      14.49
# 1  0.094   -0.9638            0.445370                      44.54
# 2  0.275    0.9495            0.505303                      49.96
# 3  0.163    0.9943            0.508333                      50.26
# 4  0.181    0.9873            0.503571                      17.23
#
#    flesch_kincaid_grade  Perplexity Score  \
# 0                  16.9         14.795133
# 1                  11.6         10.150987
# 2                  11.6         12.728074
# 3                  11.4         10.289102
# 4                  15.8         11.612104
#
#                                           split_text  no_discourse_markers  \
# 0  [The, journey, to, understanding, driverless, ...                    18
# 1  [As, a, sixth-grade, student,, I, believe, tha...                    22
# 2  [Failure, is, a, crucial, aspect, of, achievin...                     5
# 3  [Introduction:\n\nAs, a, scientist, at, NASA,,...                     7
# 4  [I, do, not, agree, with, the, principal's, de...                    18
#
#    no_pronouns  mean_words_per_sentence  grammatical_errors
# 0            0                20.300000                  16
# 1            6                17.050000                  21
# 2            8                17.666667                  10
# 3            7                19.277778                  47
# 4            3                18.562500                  31

# %%
human['grammatical_errors'] = human['paraphrased'].apply(detect_grammatical_errors)
human.head()
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
#
#         flesch_kincaid_grade  Perplexity Score  \
# 253833                   9.9         88.486298
# 86048                    7.3         23.002769
# 1306                     9.1         27.911303
# 282922                   8.1         29.663225
# 247952                   5.1         17.708487
#
#                                                split_text  \
# 253833  [So, y, would, be, talking, About, now, people...
# 86048   [Since, we, had, sent, surveyors, to, Mars, we...
# 1306    [Dear, State, Senator,, I, am, here, to, infor...
# 282922  [Dear, Principal:\n\nI, think, that, this, sit...
# 247952  [Hello,, my, name, is, Luke, Merger,, and, I, ...
#
#         no_discourse_markers  no_pronouns  mean_words_per_sentence  \
# 253833                    28          151                24.680000
# 86048                     26          127                18.260870
# 1306                      24          171                22.296296
# 282922                    10           42                21.125000
# 247952                    19           95                13.117647
#
#         grammatical_errors
# 253833                  74
# 86048                   51
# 1306                    83
# 282922                  20
# 247952                  63

# %% [markdown]
# #### Named entities

# %%
# !pip install spacy download en_core_web_sm
import spacy
# Out:
# Requirement already satisfied: spacy in c:\users\asus\anaconda3\lib\site-packages (3.7.4)
# Collecting download
#   Using cached download-0.3.5-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: en_core_web_sm in c:\users\asus\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (22.0)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (2.6.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: six in c:\users\asus\anaconda3\lib\site-packages (from download) (1.16.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\asus\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\asus\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\asus\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\asus\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\asus\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: download
# Successfully installed download-0.3.5

# %%
from spacy.cli import download

download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("en_core_web_sm")

# Function to perform named entity recognition and count named entities
def count_named_entities(text):
    doc = nlp(text)
    named_entity_counts = {}
    for ent in doc.ents:
        entity_type = ent.label_
        if entity_type in named_entity_counts:
            named_entity_counts[entity_type] += 1
        else:
            named_entity_counts[entity_type] = 1
    return len(named_entity_counts)

# Apply function to DataFrame
paraphrased['named_entity_counts'] = paraphrased['paraphrased'].apply(count_named_entities)
paraphrased.head()
# Out:
#    Unnamed: 0                                               text  generated  \
# 0       79241  \n\nStarting our journey towards understanding...        1.0
# 1      386827  As a student PN grade 6, I believe that single...        1.0
# 2       84966  Failure plays a crucial role in the pursuit of...        1.0
# 3       43982  Introduction:\n\nAs a scientist at NASA, I hav...        1.0
# 4       97180  I disagree Pith the principal's decision that ...        1.0
#
#                                          paraphrased  length    neg    neu  \
# 0  The journey to understanding driverless cars b...    1534  0.052  0.739
# 1  As a sixth-grade student, I believe that dispo...    2260  0.145  0.761
# 2  Failure is a crucial aspect of achieving succe...     641  0.153  0.572
# 3  Introduction:\n\nAs a scientist at NASA, I hav...    2167  0.030  0.807
# 4  I do not agree with the principal's decision t...    2162  0.060  0.759
#
#      pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 0  0.209    0.9869            0.448016                      14.49
# 1  0.094   -0.9638            0.445370                      44.54
# 2  0.275    0.9495            0.505303                      49.96
# 3  0.163    0.9943            0.508333                      50.26
# 4  0.181    0.9873            0.503571                      17.23
#
#    flesch_kincaid_grade  Perplexity Score  \
# 0                  16.9         14.795133
# 1                  11.6         10.150987
# 2                  11.6         12.728074
# 3                  11.4         10.289102
# 4                  15.8         11.612104
#
#                                           split_text  no_discourse_markers  \
# 0  [The, journey, to, understanding, driverless, ...                    18
# 1  [As, a, sixth-grade, student,, I, believe, tha...                    22
# 2  [Failure, is, a, crucial, aspect, of, achievin...                     5
# 3  [Introduction:\n\nAs, a, scientist, at, NASA,,...                     7
# 4  [I, do, not, agree, with, the, principal's, de...                    18
#
#    no_pronouns  mean_words_per_sentence  grammatical_errors  \
# 0            0                20.300000                  16
# 1            6                17.050000                  21
# 2            8                17.666667                  10
# 3            7                19.277778                  47
# 4            3                18.562500                  31
#
#    named_entity_counts
# 0                    1
# 1                    2
# 2                    0
# 3                    8
# 4                    0

# %%
human['named_entity_counts'] = human['paraphrased'].apply(count_named_entities)
human.head()
# Out:
#                                                      text  generated  \
# 253833  So y would be talking About now people should ...        0.0
# 86048   Since we had sent surveyors to Mars we have fo...        0.0
# 1306    Dear State Senator, I am here to inform you th...        0.0
# 282922  Dear Principal:\n\nI think that this situation...        0.0
# 247952  Hello, my name is Luke Merger, and I am in the...        0.0
#
#                                               paraphrased  length    neg  \
# 253833  So y would be talking About now people should ...    3267  0.062
# 86048   Since we had sent surveyors to Mars we have fo...    2261  0.036
# 1306    Dear State Senator, I am here to inform you th...    3348  0.070
# 282922  Dear Principal:\n\nI think that this situation...     880  0.027
# 247952  Hello, my name is Luke Merger, and I am in the...    2395  0.042
#
#           neu    pos  compound  subjectivity_score  flesch_reading_ease_score  \
# 253833  0.745  0.193    0.9988            0.508549                      70.57
# 86048   0.860  0.103    0.9823            0.532793                      77.27
# 1306    0.778  0.152    0.9947            0.602583                      67.18
# 282922  0.891  0.082    0.6808            0.333333                      75.13
# 247952  0.814  0.145    0.9936            0.407160                      82.95
#
#         flesch_kincaid_grade  Perplexity Score  \
# 253833                   9.9         88.486298
# 86048                    7.3         23.002769
# 1306                     9.1         27.911303
# 282922                   8.1         29.663225
# 247952                   5.1         17.708487
#
#                                                split_text  \
# 253833  [So, y, would, be, talking, About, now, people...
# 86048   [Since, we, had, sent, surveyors, to, Mars, we...
# 1306    [Dear, State, Senator,, I, am, here, to, infor...
# 282922  [Dear, Principal:\n\nI, think, that, this, sit...
# 247952  [Hello,, my, name, is, Luke, Merger,, and, I, ...
#
#         no_discourse_markers  no_pronouns  mean_words_per_sentence  \
# 253833                    28          151                24.680000
# 86048                     26          127                18.260870
# 1306                      24          171                22.296296
# 282922                    10           42                21.125000
# 247952                    19           95                13.117647
#
#         grammatical_errors  named_entity_counts
# 253833                  74                    6
# 86048                   51                    4
# 1306                    83                    5
# 282922                  20                    2
# 247952                  63                   11

# %% [markdown]
# #### Concatenating both dataframes

# %%
ai_paraphrased_sample = paraphrased.sample(1000)

# %%
ai_human_mix = pd.concat([ai_paraphrased_sample, human])

# %%
ai_human_mix.to_csv('ai_human_with_features.csv')
